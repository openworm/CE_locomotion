# %%
from IPython.display import Image, JSON

# %% [markdown]
# Results and progress files are stored in a directory. Simulations (after potentially changing some parameters etc) are restarted from them and update them. This notebook loads the figures from one of the outputFolder directories you can set here. (Only choose one of these directories!)

# %%
outputFolderName="notebooks/example_W2D18L"
#outputFolderName="notebooks/example_W2D18L_modified"

# %% [markdown]
# After a simulation has been performed the output folder contains various files. These files are updated every time the code is run and should be reloaded in this notebook after every simulation to view the most recent version. The fitness.dat file shows the phenotype fitness history for the generations so far. The first column is the generation number, the second the fitness of the best phenotype, the third the average fitness of the population and the fourth the standard deviation of the population fitness. This file updates dynamically and can be reloaded during an evolution to examine the progress. The evolution can be interrupted if desired and a simulation performed or the evolution resumed from the last checkpoint (by default every five generations):

# %%
with open(outputFolderName + '/fitness.dat') as f:
    print(f.read())
# Out:
# 0.0 0.005140486263 0.0002564167164 8.298564032e-07
# 1.0 0.02636945301 0.0005912672547 1.111972828e-05
# 2.0 0.03462511259 0.001565752281 3.271541111e-05
# 3.0 0.03462511259 0.002125315681 4.860693142e-05
# 4.0 0.05449211176 0.002394573131 8.612981048e-05
# 5.0 0.05449211176 0.002526244012 9.112897679e-05
# 6.0 0.05449211176 0.003082950688 9.675264759e-05
# 7.0 0.05539346033 0.004113758959 0.0001426422078
# 8.0 0.05539346033 0.004009155175 0.0001573306807
# 9.0 0.1997058755 0.008682807969 0.0007703899971
# 10.0 0.1997058755 0.01017300244 0.00116759984
# 11.0 0.1997058755 0.01017300244 0.00116759984
# 12.0 0.1997058755 0.01025910587 0.001352279166
# 13.0 0.1997058755 0.009129288077 0.00112955183
# 14.0 0.1997058755 0.01249707129 0.001638785032
# 15.0 0.1997058755 0.0138592715 0.002014660481
# 16.0 0.2019646421 0.02050048399 0.002902083915
# 17.0 0.2025969639 0.02295485863 0.003315871814
# 18.0 0.2224264226 0.02403134944 0.003491409346
# 19.0 0.2224264226 0.03138753899 0.004290924255
# 20.0 0.2224264226 0.03650167883 0.005371751444
# 21.0 0.2224264226 0.02360449162 0.003295095946
# 22.0 0.2559408814 0.02521244538 0.004219865064
# 23.0 0.2559408814 0.02404188694 0.00394071442
# 24.0 0.2559408814 0.02096335082 0.003397884678
# 25.0 0.2559408814 0.02763948451 0.004326892325
# 26.0 0.2559408814 0.03677291923 0.005607838384
# 27.0 0.2559408814 0.04054751501 0.006565624357
# 28.0 0.2622438403 0.04293006666 0.006786366598
# 29.0 0.2622438403 0.05814719947 0.009045922855
# 30.0 0.290523702 0.0508854008 0.007009370249
# 31.0 0.290523702 0.06354527963 0.01005162136
# 32.0 0.290523702 0.04728757467 0.008374974252
# 33.0 0.290523702 0.04559040782 0.007752090341
# 34.0 0.290523702 0.05223076077 0.008385842484
# 35.0 0.290523702 0.05547807249 0.008574137104
# 36.0 0.2944177862 0.06260694471 0.01103673909
# 37.0 0.2944177862 0.05565933559 0.009400006781
# 38.0 0.3040346671 0.06339041317 0.01033882375
# 39.0 0.3092958282 0.07975427172 0.01268191748
# 40.0 0.3135581422 0.06395582938 0.01159157145
# 41.0 0.3135581422 0.05334353147 0.00954198418
# 42.0 0.3135581422 0.05552841923 0.01034436902
# 43.0 0.3135581422 0.04822256212 0.009732259241
# 44.0 0.3194078947 0.05472220431 0.01055254757
# 45.0 0.3194078947 0.04937511885 0.00822974986
# 46.0 0.3194078947 0.0666763045 0.0118957568
# 47.0 0.3194078947 0.06608070761 0.0123635327
# 48.0 0.3328879243 0.07326103499 0.01368639693
# 49.0 0.3328879243 0.0843644043 0.01358458654
# 50.0 0.3328879243 0.1068761881 0.01408617225
# 51.0 0.3376807879 0.1149393266 0.01535641789
# 52.0 0.3389755484 0.09995043897 0.01426852051
# 53.0 0.3389755484 0.09082611418 0.01401435821
# 54.0 0.3467626713 0.09614734035 0.01534293398
# 55.0 0.3489468127 0.0727747538 0.01313961788
# 56.0 0.3868083972 0.1026210703 0.0172392412
# 57.0 0.3868083972 0.07300038533 0.01187649544
# 58.0 0.3896479593 0.08191976851 0.01736541671
# 59.0 0.3896479593 0.06181449938 0.01364358055
# 60.0 0.3896479593 0.06946042971 0.01595910194
# 61.0 0.3896479593 0.05596832653 0.01308815429
# 62.0 0.3896479593 0.08458369008 0.01608649497
# 63.0 0.3896479593 0.07735016039 0.01650347999
# 64.0 0.4122927056 0.09180760952 0.01768192016
# 65.0 0.4122927056 0.1016798396 0.01940644314
# 66.0 0.4122927056 0.08141710951 0.01500833563
# 67.0 0.4122927056 0.06796025329 0.01410142209
# 68.0 0.4125454682 0.06486618087 0.01569515002
# 69.0 0.420402823 0.0828830458 0.0185658279
# 70.0 0.420402823 0.1090589101 0.02293054057
# 71.0 0.4355614041 0.09212933475 0.02130609711
# 72.0 0.4461904028 0.09184485555 0.02198197364
# 73.0 0.4461904028 0.06582588183 0.01868911255
# 74.0 0.4547785353 0.08514099377 0.02244989241
# 75.0 0.4547785353 0.08294183726 0.02171750421
# 76.0 0.4547785353 0.06387984331 0.01706542506
# 77.0 0.4547785353 0.06698160154 0.0177704468
# 78.0 0.4681982175 0.1021651352 0.0232102797
# 79.0 0.4717414356 0.1075424676 0.02647420476
# 80.0 0.4717414356 0.1218476525 0.02755370204
# 81.0 0.4897857306 0.1023267513 0.02488361615
# 82.0 0.5271610664 0.1347035964 0.03057012507
# 83.0 0.5271610664 0.1504049011 0.0304545159
# 84.0 0.5271610664 0.1306846329 0.03146455984
# 85.0 0.5317847259 0.1384681967 0.03131467849
# 86.0 0.5317847259 0.1324089875 0.03259790476
# 87.0 0.5317847259 0.1305359076 0.03209230131
# 88.0 0.541518595 0.1587284859 0.03578572591
# 89.0 0.541518595 0.1593648664 0.04050476219
# 90.0 0.5730706982 0.1448386027 0.04209096154
# 91.0 0.5730706982 0.1729082583 0.04206277083
# 92.0 0.5730706982 0.1932109958 0.04785253453
# 93.0 0.5761344048 0.1780314523 0.04612841673
# 94.0 0.5761344048 0.1583163472 0.0437583579
# 95.0 0.5761344048 0.1139610069 0.03614033511
# 96.0 0.5761344048 0.1288403227 0.04060732104
# 97.0 0.5761344048 0.1287043641 0.04096992767
# 98.0 0.5761344048 0.1643848194 0.04831091033
# 99.0 0.5809591876 0.1770182688 0.04768887184
# 100.0 0.5809591876 0.1615476986 0.05013356943
# 101.0 0.5809591876 0.1687151536 0.04956358477
# 102.0 0.5809591876 0.1819651044 0.04501694116
# 103.0 0.5809591876 0.193861617 0.04997653303
# 104.0 0.5809591876 0.1697420326 0.04986179254
# 105.0 0.5809591876 0.1550576137 0.04597899115
# 106.0 0.5809591876 0.1716456395 0.04515245731
# 107.0 0.5826260426 0.1575791262 0.04772843488
# 108.0 0.5826260426 0.1569351293 0.04261011842
# 109.0 0.5826260426 0.2058479404 0.05202930759
# 110.0 0.5908227382 0.2176821054 0.05555685568
# 111.0 0.593289356 0.207777615 0.04935758335
# 112.0 0.6127631153 0.2192022635 0.05373702612
# 113.0 0.6127631153 0.2172336072 0.04959861595
# 114.0 0.6200357814 0.2296596903 0.04771595546
# 115.0 0.6200357814 0.2120536188 0.05043166398
# 116.0 0.6200357814 0.2245916279 0.04967296368
# 117.0 0.6200357814 0.1981325133 0.04815004378
# 118.0 0.6322277257 0.1782363303 0.05108463405
# 119.0 0.6322277257 0.2221541652 0.05907232826
# 120.0 0.636407553 0.2675700119 0.05794381476
# 121.0 0.636407553 0.2114395667 0.05523616534
# 122.0 0.636407553 0.2142433411 0.05929404472
# 123.0 0.636407553 0.188818341 0.04857063319
# 124.0 0.636407553 0.2013135331 0.05743199796
# 125.0 0.6452593364 0.2236289114 0.0604434375
# 126.0 0.6452593364 0.1999280867 0.05625587243
# 127.0 0.6775399036 0.2026888059 0.06265433507
# 128.0 0.6775399036 0.2443057545 0.06280565857
# 129.0 0.6775399036 0.2405297505 0.07140708173
# 130.0 0.6802385951 0.2441640088 0.05965042354
# 131.0 0.6802385951 0.2069447395 0.06565187229
# 132 0.6802385951 0.2069447395 0.06565187229
# 133 0.6802385951 0.2114344006 0.06107213388
# 134 0.6802385951 0.1596522125 0.05118101692
# 135 0.6802385951 0.1926380639 0.05460375116
# 136 0.6802385951 0.2220164968 0.06550612858
# 137 0.6802385951 0.1768965254 0.06084790528
# 138 0.6802385951 0.2147786875 0.0699456232
# 139 0.6933665294 0.1960695988 0.0685196379
# 140 0.6933665294 0.2366642918 0.07310425998
# 141 0.7150975612 0.2480356667 0.06654730102
# 142 0.7150975612 0.257407108 0.06824910617
# 143 0.7150975612 0.301589886 0.07402348979
# 144 0.7150975612 0.2685361142 0.07534667898
# 145 0.7150975612 0.2184878449 0.07906789504
# 146 0.7150975612 0.2056074215 0.07256762231
# 147 0.7150975612 0.2068027499 0.07166611094
# 148 0.7150975612 0.2112351124 0.07569451731
# 149 0.7150975612 0.2338461204 0.08416331117
# 150 0.7150975612 0.2333684646 0.08325967652
# 151 0.7150975612 0.1953613369 0.07875765841
# 152 0.7150975612 0.1409123209 0.05982543707
# 153 0.7194266787 0.218760485 0.08312968595
# 154 0.7194266787 0.282687946 0.09141007936
# 155 0.7355735487 0.2115356623 0.08390509613
# 156 0.7355735487 0.2565145194 0.09502861585
# 157 0.748490436 0.2116450499 0.0859693407
# 158 0.748490436 0.2124599578 0.08792317167
# 159 0.748490436 0.1807332734 0.07878758113
# 160 0.748490436 0.211484307 0.08438066736
# 161 0.748490436 0.2376946161 0.09291808336
# 162 0.7721968913 0.2434782463 0.08448649374
# 163 0.7721968913 0.2345068026 0.08365400655
# 164 0.7721968913 0.2193251794 0.08887366865
# 165 0.7721968913 0.2008480645 0.07818441253
# 166 0.7721968913 0.2329319098 0.08832428136
# 167 0.7721968913 0.1883764159 0.08067469733
# 168 0.7721968913 0.2353622492 0.0852123329
# 169 0.7721968913 0.2179049288 0.08564123014
# 170 0.7721968913 0.2158700255 0.09434296223
# 171 0.7721968913 0.2342835284 0.09125587358
# 172 0.7721968913 0.2510128811 0.09799942922
# 173 0.7721968913 0.2423529054 0.1029283492
# 174 0.7721968913 0.2037848281 0.09616105234
# 175 0.7721968913 0.1910316735 0.09025206049
# 176 0.7721968913 0.1983732874 0.08925659604
# 177 0.7721968913 0.2322568728 0.09706176101
# 178 0.7721968913 0.1899098001 0.08192311125
# 179 0.7721968913 0.1714120528 0.08265401252
# 180 0.7721968913 0.2025202607 0.08576220081
# 181 0.7721968913 0.2186193757 0.08507806098
# 182 0.7721968913 0.2325960988 0.09321619325

# %% [markdown]
# Display a time series of simulation results of current best phenotype. The transient and duration time intervals for this are set with the parameters 'simtransient' and 'simduration'.

# %%
Image(filename=outputFolderName + '/ExampleActivity.png')

# %% [markdown]
# Display worm motion in larger plot:

# %%
Image(filename=outputFolderName + '/Motion.png')

# %% [markdown]
# Display a more detailed plot of the first 20 seconds:

# %%
Image(filename=outputFolderName + '/behavior.png')

# %% [markdown]
# When the genetic algorithm optimization is performed, some model parameters are fined tuned to produce a particular behaviour for the phenotype. The following figure (top left panel) shows how the fitness, (between zero and unity) in log scale, for the best phenotype in the population and the population average phenotype varies over successive generations. The other five panels show how the values of the evolvable model parameters vary over successive generations. The optimizable parameters are shown in the bottom right panel. For example there may be parameters associated with chemical connection weights in the nervous system (denoted ns_chemcons), parameters associated with the stretch receptor gains (sr_head_gain, sr_vnc_gain) and others associated with the VNC nervous system to muscle connectivity structure (denoted vnc_18_dd_vda_vdp, for example). Many parameters will have the same name, for example there may be multiple "ns_cells_bias", these are bias parameters for different cells, or different sets of cells, since the same evolvable parameter may be used across multiple cells. The figure shows their actual values (top right), percent change from the intial state (middle left), signed log of the percent change (bottom left) all averaged across the whole population. The percent change values for the best phenotype is also shown (middle right).

# %%
Image(filename=outputFolderName + '/EvoHist.png')

# %% [markdown]
# We also plot the current and initial values for each of the evolvable parameters, and their percent variations.

# %%
Image(filename=outputFolderName + '/Evolution_averages_2.png')

# %% [markdown]
# For simpler visualization we also plot the evolution history for these evolvable parameters averaged into similar type classes. For example the NS_ChemWei parameters are averaged together.

# %%
Image(filename=outputFolderName + '/EvoHist_av.png')

# %% [markdown]
# And similarly for their final and initial values:

# %%
Image(filename=outputFolderName + '/Evolution_averages.png')
