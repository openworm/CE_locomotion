# %%
# !rm -rf testruns/exW2DCEFR

# %%
from run_main import run

run(
    simduration=10,
    simtransient=10,
    duration=10,
    transient=10,
    maxGens=5,
    popSize=26,
    RandSeed=81235,
    modelName="W2DCE",
    modelFolder="Worm2D",
    outputFolderName="testruns/exW2DCEFR",
    doEvol=True,
    overwrite=True,
    checkPointInterval=5,
    reRand=True,
    doPlotEvol=True,
    doNML=False,
    doCPT=True,
    evoType="EvoCE",
    doReverse=2,
    SRType="None",
    ABLevel=3,
    doForwardFirst=False,
    # SRType="SR_TRANS_CONTRACT",
    # SRType = "SR_TRANS_STRETCH",
    # SRType = "SR_TRANS_ABS",
    # SRType = "SR_TRANS_NEG"
    randInitState = True,
    doOrigMuscInput = False,
    doOrigSRInput = False,
    doLegacy = False
    # MutVar = 0.5
)
# Out:
# Directory 'testruns/exW2DCEFR' created successfully.
# ['Worm2D/main_osc', '--doReverse', '2', '--SRType', 'None', '--AB_output_level', '3', '--randomInitialState', '1', '--doOrigMuscInput', '0', '--doOrigSRInput', '0', '--doForwardFirst', '0', '--doLegacy', '0', '-R', '81235', '-p', '26', '-d', '10', '-t', '10', '--maxgens', '5', '-sd', '10', '-st', '10', '--doevol', '1', '-cpt', '5', '--dorandinit', '0', '--donml', '0', '--folder', 'testruns/exW2DCEFR', '--modelname', 'W2DCE', '--domusc', '0', '-docpt', '1', '--evoType', 'EvoCE']
# evotype EvoCE
# docpt 1
# const from default testruns/exW2DCEFR/EvoWJbest.gen.dat 17
# worm2dbase add pars to json
# idi
# worm2dbase add pars to json
# idi
# worm2dbase add pars to json
# idi
# worm2dbase add pars to json
# idi
# worm2dbase add pars to json
# idi
# worm2dbase add pars to json
# idi
# jsonfile testruns/exW2DCEFR/worm_data_evo.json
# shhd
# jsonfile testruns/exW2DCEFR/worm_data_evo.json
# shds 81235 0.005 10
# simrandseed 81235
# worm2dbase add pars to json
# idi
# {"condval":1}
# running simulation sim
# {"condval":0}
# running simulation sim
#
# Saved plot image to: testruns/exW2DCEFR/ExampleActivity.png
# Simulation
# 0.0
# 20.0
# 40.0
# 60.0
# 80.0
# 100.0
# cell ind is  24
# cell ind is  25
# cell ind is  26
# cell ind is  28
# cell ind is  29
# cell ind is  27
# Evolvable
# value
# 0
# name
# checkDict
# ['W2DCE_SR_A', 'W2DCE_SR_B', 'W2DCE_Bias', 'W2DCE_Bias', 'W2DCE_Bias', 'W2DCE_Self_cons', 'W2DCE_Self_cons', 'W2DCE_Self_cons', 'W2DCE_Syn_E', 'W2DCE_Syn_E', 'W2DCE_Syn_I', 'W2DCE_Syn_I', 'W2DCE_Gap', 'W2DCE_Gap', 'W2DCE_NMJ_E', 'W2DCE_NMJ_E', 'W2DCE_NMJ_I']
# (6, 52)
# ['W2DCE_Bias', 'W2DCE_Gap', 'W2DCE_NMJ_E', 'W2DCE_NMJ_I', 'W2DCE_SR_A', 'W2DCE_SR_B', 'W2DCE_Self_cons', 'W2DCE_Syn_E', 'W2DCE_Syn_I']
# Saved plot image to: testruns/exW2DCEFR/Evolution_averages_redo.png
# Saved plot image to: testruns/exW2DCEFR/Evolution_averages_redo_2.png
# 17
# (6, 52)
# ['W2DCE_Bias', 'W2DCE_Gap', 'W2DCE_NMJ_E', 'W2DCE_NMJ_I', 'W2DCE_SR_A', 'W2DCE_SR_B', 'W2DCE_Self_cons', 'W2DCE_Syn_E', 'W2DCE_Syn_I']
# Saved plot image to: testruns/exW2DCEFR/Evolution.png
# Saved plot image to: testruns/exW2DCEFR/Evolution_averages.png
